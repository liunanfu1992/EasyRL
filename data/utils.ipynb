# %%
import pandas as pd

# %%
df = pd.read_parquet('/run/determined/workdir/jiayanglyu/EasyRL/data/rl_train.parquet')
df
# Out:
#                               data_source  \
# 0      train-math-numinamath1.5_olympiads
# 1                   train-math-deepscaler
# 2                   train-math-deepscaler
# 3      train-math-numinamath1.5_olympiads
# 4                   train-math-deepscaler
# ...                                   ...
# 9669  train-math-numinamath1.5_cn_contest
# 9670   train-math-numinamath1.5_olympiads
# 9671   train-math-numinamath1.5_olympiads
# 9672                train-math-deepscaler
# 9673                train-math-deepscaler
#
#                                                  prompt           ground_truth
# 0     [{'content': '33. How many six-digit numbers a...                  15625
# 1     [{'content': 'Each of 8 balls is randomly and ...         \frac{35}{128}
# 2     [{'content': 'Five people are crowding into a ...                    240
# 3     [{'content': '32. As shown in the figure, rays...                     15
# ...
